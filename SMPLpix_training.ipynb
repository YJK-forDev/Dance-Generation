# %% [markdown]
# ![](https://user-images.githubusercontent.com/8117267/116595226-621dc600-a923-11eb-85d4-f52a5b9f265c.gif)
# ###SMPLpix Training Demo.
#
# **Author**: [Sergey Prokudin](https://ps.is.mpg.de/people/sprokudin).
# [[Project Page](https://sergeyprokudin.github.io/smplpix/)]
# [[Paper](https://arxiv.org/pdf/2008.06872.pdf)]
# [[Video](https://www.youtube.com/watch?v=JY9t4xUAouk)]
# [[GitHub](https://github.com/sergeyprokudin/smplpix)]
#
# This notebook contains an example of training script for SMPLpix rendering module.
#
# To prepare the data with your own video, use the [SMPLpix dataset preparation notebook](https://colab.research.google.com/github//sergeyprokudin/smplpix/blob/main/colab_notebooks/Convert_Video_to_SMPLpix_Dataset.ipynb).

# %% [markdown]
# ### Install the SMPLpix framework:

# %%
# !git clone https://github.com/sergeyprokudin/smplpix

# !python setup.py install
# Out:
# running install
# /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/setuptools/command/easy_install.py:144: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# running bdist_egg
# running egg_info
# creating smplpix.egg-info
# writing smplpix.egg-info/PKG-INFO
# writing dependency_links to smplpix.egg-info/dependency_links.txt
# writing requirements to smplpix.egg-info/requires.txt
# writing top-level names to smplpix.egg-info/top_level.txt
# writing manifest file 'smplpix.egg-info/SOURCES.txt'
# reading manifest file 'smplpix.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'smplpix.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/smplpix
# copying smplpix/train.py -> build/lib/smplpix
# copying smplpix/vgg.py -> build/lib/smplpix
# copying smplpix/args.py -> build/lib/smplpix
# copying smplpix/dataset.py -> build/lib/smplpix
# copying smplpix/unet.py -> build/lib/smplpix
# copying smplpix/__init__.py -> build/lib/smplpix
# copying smplpix/eval.py -> build/lib/smplpix
# copying smplpix/utils.py -> build/lib/smplpix
# copying smplpix/training.py -> build/lib/smplpix
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/smplpix
# copying build/lib/smplpix/train.py -> build/bdist.linux-x86_64/egg/smplpix
# copying build/lib/smplpix/vgg.py -> build/bdist.linux-x86_64/egg/smplpix
# copying build/lib/smplpix/args.py -> build/bdist.linux-x86_64/egg/smplpix
# copying build/lib/smplpix/dataset.py -> build/bdist.linux-x86_64/egg/smplpix
# copying build/lib/smplpix/unet.py -> build/bdist.linux-x86_64/egg/smplpix
# copying build/lib/smplpix/__init__.py -> build/bdist.linux-x86_64/egg/smplpix
# copying build/lib/smplpix/eval.py -> build/bdist.linux-x86_64/egg/smplpix
# copying build/lib/smplpix/utils.py -> build/bdist.linux-x86_64/egg/smplpix
# copying build/lib/smplpix/training.py -> build/bdist.linux-x86_64/egg/smplpix
# byte-compiling build/bdist.linux-x86_64/egg/smplpix/train.py to train.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/smplpix/vgg.py to vgg.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/smplpix/args.py to args.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/smplpix/dataset.py to dataset.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/smplpix/unet.py to unet.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/smplpix/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/smplpix/eval.py to eval.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/smplpix/utils.py to utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/smplpix/training.py to training.cpython-310.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying smplpix.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying smplpix.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying smplpix.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying smplpix.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying smplpix.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating dist
# creating 'dist/smplpix-1.0-py3.10.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing smplpix-1.0-py3.10.egg
# Copying smplpix-1.0-py3.10.egg to /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages
# Adding smplpix 1.0 to easy-install.pth file
#
# Installed /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/smplpix-1.0-py3.10.egg
# Processing dependencies for smplpix==1.0
# Searching for pyrender
# Reading https://pypi.org/simple/pyrender/
# /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning:  is an invalid version and will not be supported in a future release
#   warnings.warn(
# Downloading https://files.pythonhosted.org/packages/28/88/174c28b9d3d03cf6d8edb6f637458f30f1cf1a2bd7a617cbd9dadb1740f6/pyrender-0.1.45-py3-none-any.whl#sha256=5cf751d1f21fba4640e830cef3a0b5a95ed0f05677bf92c6b8330056b4023aeb
# Best match: pyrender 0.1.45
# Processing pyrender-0.1.45-py3-none-any.whl
# Installing pyrender-0.1.45-py3-none-any.whl to /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages
# Adding pyrender 0.1.45 to easy-install.pth file
#
# Installed /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/pyrender-0.1.45-py3.10.egg
# Searching for trimesh
# Reading https://pypi.org/simple/trimesh/
# Downloading https://files.pythonhosted.org/packages/f0/0a/4c96c429485a440b99b86aa2991630e37051051df04a7aaee85655e6f16c/trimesh-3.16.0-py3-none-any.whl#sha256=613c1630d6e7cef2857095df87c301ef30b2090b7838a0d21c1625293c6dddc2
# Best match: trimesh 3.16.0
# Processing trimesh-3.16.0-py3-none-any.whl
# Installing trimesh-3.16.0-py3-none-any.whl to /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages
# Adding trimesh 3.16.0 to easy-install.pth file
#
# Installed /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/trimesh-3.16.0-py3.10.egg
# Searching for PyOpenGL==3.1.0
# Reading https://pypi.org/simple/PyOpenGL/
# Downloading https://files.pythonhosted.org/packages/ce/33/ef0e3b40a3f4cbfcfb93511652673fb19d07bafac0611f01f6237d1978ed/PyOpenGL-3.1.0.zip#sha256=efa4e39a49b906ccbe66758812ca81ced13a6f26931ab2ba2dba2750c016c0d0
# Best match: PyOpenGL 3.1.0
# Processing PyOpenGL-3.1.0.zip
# Writing /tmp/easy_install-tztti2t9/PyOpenGL-3.1.0/setup.cfg
# Running PyOpenGL-3.1.0/setup.py -q bdist_egg --dist-dir /tmp/easy_install-tztti2t9/PyOpenGL-3.1.0/egg-dist-tmp-5asv7ffw
# warning: no previously-included files matching '*.odt' found anywhere in distribution
# warning: no previously-included files matching '*.odp' found anywhere in distribution
# warning: no previously-included files matching '.cvsignore' found anywhere in distribution
# warning: no previously-included files matching '*.diff' found anywhere in distribution
# warning: no previously-included files found matching 'src/*.h'
# warning: no previously-included files found matching 'src/*.xml'
# warning: no previously-included files found matching 'src/*.zip'
# warning: no previously-included files found matching 'src/*.pdf'
# warning: no previously-included files found matching 'src/*.zip'
# warning: no previously-included files found matching 'src/*.txt'
# warning: no files found matching 'src/win32deps.py'
# warning: no files found matching 'src/toglinstall/get_togl.py'
# warning: no files found matching 'metadata.py'
# warning: no files found matching 'ChangeLog.txt'
# warning: no previously-included files found matching 'OpenGL_accelerate'
# /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
#   File "build/bdist.linux-x86_64/egg/OpenGL/GL/SGIX/async.py", line 58
#     from OpenGL.raw.GL.SGIX.async import *
#                             ^^^^^
# SyntaxError: invalid syntax
#
# zip_safe flag not set; analyzing archive contents...
# OpenGL.Tk.__pycache__.__init__.cpython-310: module references __file__
# OpenGL.platform.__pycache__.ctypesloader.cpython-310: module references __file__
# creating /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/PyOpenGL-3.1.0-py3.10.egg
# Extracting PyOpenGL-3.1.0-py3.10.egg to /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages
#   File "/home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/PyOpenGL-3.1.0-py3.10.egg/OpenGL/GL/SGIX/async.py", line 58
#     from OpenGL.raw.GL.SGIX.async import *
#                             ^^^^^
# SyntaxError: invalid syntax
#
# Adding PyOpenGL 3.1.0 to easy-install.pth file
#
# Installed /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/PyOpenGL-3.1.0-py3.10.egg
# Searching for freetype-py
# Reading https://pypi.org/simple/freetype-py/
# /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: py-0.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning:  is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: py-0.1.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: py-0.2.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: py-0.3.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: py-0.3.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: py-0.3.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: py-0.3.3 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: py-0.4 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: py-0.4.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: py-0.4.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: py-0.5.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: py-0.5.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: py-0.5.3 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: py-1.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: py-1.0.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: py-1.0.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: py-1.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: py-1.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: py-1.2.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: py-2.0.0.post3 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: py-2.0.0.post4 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: py-2.0.0.post5 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: py-2.0.0.post6 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: py-2.1.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: py-2.1.0.post1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: py-2.2.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: py-2.2.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: py-2.3.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# Downloading https://files.pythonhosted.org/packages/47/4a/eaf409f4dee179aa8984b5cd6ff0130b2523c00f37f5221629b5df4b6918/freetype_py-2.3.0-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl#sha256=c8f17c3ac35dc7cc9571ac37a00a6daa428a1a6d0fe6926a77d16066865ed5ef
# Best match: freetype-py 2.3.0
# Processing freetype_py-2.3.0-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl
# Installing freetype_py-2.3.0-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl to /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages
# Adding freetype-py 2.3.0 to easy-install.pth file
#
# Installed /home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/freetype_py-2.3.0-py3.10-linux-x86_64.egg
# error: torch 1.13.0 is installed but torch==1.11.0 is required by {'torchvision'}

# %% [markdown]
# ### To train the model on the provided [demo dataset](https://www.dropbox.com/s/coapl05ahqalh09/smplpix_data_test_final.zip?dl=0), simply run:

# %%
# !cd /content/smplpix
# !python smplpix/train.py \
        --workdir='./smplpix_logs/' \
        --resume_training=0 \
        --data_dir='./' \
        --downsample_factor=4 \
        --n_epochs=100 \
        --sched_patience=2 \
        --eval_every_nth_epoch=10 \
        --batch_size=4 \
        --learning_rate=1.0e-3 \
        --n_unet_blocks=5 \
        --aug_prob=0.0

        #--data_url='https://www.dropbox.com/s/coapl05ahqalh09/smplpix_data_test_final.zip?dl=0' \
# Out:
# /bin/bash: line 0: cd: /content/smplpix: No such file or directory
# ******************************************************************************************
# ****************************** SMPLpix Training Loop  ************************************
# ******************************************************************************************
# ******** Copyright (c) 2021 - now, Sergey Prokudin (sergey.prokudin@gmail.com) ***********
# ****************************************************************************************+*
#
#
# ARGUMENTS:
# Namespace(workdir='./smplpix_logs/', data_dir='./', resume_training=0, data_url=None, n_input_channels=3, n_output_channels=3, sigmoid_output=True, n_unet_blocks=5, batch_size=4, device='cuda', downsample_factor=1, n_epochs=100, learning_rate=0.001, eval_every_nth_epoch=10, sched_patience=2, aug_prob=0.0, save_target=1, checkpoint_path=None)
# defining the neural renderer model (U-Net)...
# starting training from scratch, cleaning the log dirs...
# starting training...
#   0%|                                                   | 0/100 [00:00<?, ?it/s]/home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/torch/nn/functional.py:780: UserWarning: Note that order of the arguments: ceil_mode and return_indices will changeto match the args list in nn.MaxPool2d in a future release.
#   warnings.warn("Note that order of the arguments: ceil_mode and return_indices will change"
#
# current epoch: 0
# mean VGG loss: 0.016801
# images saved at ./smplpix_logs/logs/val_preds_0000
#   1%|▍                                        | 1/100 [00:49<1:21:11, 49.21s/it]

# %% [markdown]
# ### Optionally, we can continue training and finetune the network with lower learning rate:

# %%
# !python smplpix/train.py \
        --workdir='./smplpix_logs/' \
        --resume_training=1 \
        --data_dir='./data/smplpix_data' \
        --downsample_factor=4 \
        --n_epochs=50 \
        --sched_patience=2 \
        --eval_every_nth_epoch=10 \
        --batch_size=4 \
        --learning_rate=1.0e-4 \
        --n_unet_blocks=5

# %% [markdown]
# ### To evaluate the model on the test images, run:

# %%
# !python smplpix/eval.py \
        --workdir='./eval_logs/' \
        --checkpoint_path='./smplpix_logs/network.h5' \
        --data_dir='./test/' \
        --downsample_factor=4 \
        --save_target=1
# Out:
# ******************************************************************************************
# ****************************** SMPLpix Evaluation Loop  **********************************
# ******************************************************************************************
# ******** Copyright (c) 2021 - now, Sergey Prokudin (sergey.prokudin@gmail.com) ***********
# ARGUMENTS:
# Namespace(workdir='./eval_logs/', data_dir='./test/', resume_training=False, data_url=None, n_input_channels=3, n_output_channels=3, sigmoid_output=True, n_unet_blocks=5, batch_size=4, device='cuda', downsample_factor=4, n_epochs=500, learning_rate=0.001, eval_every_nth_epoch=10, sched_patience=3, aug_prob=0.8, save_target=1, checkpoint_path='./smplpix_logs/network.h5')
# defining the neural renderer model (U-Net)...
# loading the model from checkpoint: ./smplpix_logs/network.h5
# rendering SMPLpix predictions for ./test/...
# 0it [00:00, ?it/s]/home/cvmlserver/anaconda3/envs/11775-hw2/lib/python3.10/site-packages/torch/nn/functional.py:780: UserWarning: Note that order of the arguments: ceil_mode and return_indices will changeto match the args list in nn.MaxPool2d in a future release.
#   warnings.warn("Note that order of the arguments: ceil_mode and return_indices will change"
# 25it [00:15,  1.65it/s]
# mean VGG loss: 0.050353
# images saved at ./eval_logs/renders_
# generating video animation for data ./test/...
# executing ffmpeg -framerate 25 -pattern_type glob -i './eval_logs/renders_/*.png' -vcodec h264 -an -b:v 1M -pix_fmt yuv420p -an './eval_logs/_animation.mp4'
# ffmpeg version 5.1.2 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 10.4.0 (conda-forge gcc 10.4.0-16)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1664280367634/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1664280367634/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1664280367634/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1664280367634/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1664280367634/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libfontconfig --enable-libopenh264 --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-pthreads --enable-vaapi --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1664280367634/_build_env/bin/pkg-config
#   libavutil      57. 28.100 / 57. 28.100
#   libavcodec     59. 37.100 / 59. 37.100
#   libavformat    59. 27.100 / 59. 27.100
#   libavdevice    59.  7.100 / 59.  7.100
#   libavfilter     8. 44.100 /  8. 44.100
#   libswscale      6.  7.100 /  6.  7.100
#   libswresample   4.  7.100 /  4.  7.100
#   libpostproc    56.  6.100 / 56.  6.100
# Input #0, image2, from './eval_logs/renders_/*.png':
#   Duration: 00:00:04.00, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 657x480, 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x555ef3b53a00] width not divisible by 2 (657x480)
# Error initializing output stream 0:0 -- Error while opening encoder for output stream #0:0 - maybe incorrect parameters such as bit_rate, rate, width or height
# Conversion failed!
# something went wrong during video generation. Make sure you have ffmpeg tool installed.
# saved animation video to ./eval_logs/_animation.mp4

# %%
# @markdown ###Play the generated test video
from IPython.display import HTML
from base64 import b64encode
mp4 = open('./eval_logs/test_animation.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video width=400 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %%
import pickle as pkl

file = pkl.load(open('./00001/000.pkl', 'rb'))
print(file.keys())
# Out:
# dict_keys(['camera_rotation', 'camera_translation', 'betas', 'global_orient', 'left_hand_pose', 'right_hand_pose', 'jaw_pose', 'leye_pose', 'reye_pose', 'expression', 'body_pose'])
