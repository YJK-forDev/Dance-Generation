# %% [markdown]
# ![](https://user-images.githubusercontent.com/8117267/116876711-8defc300-ac25-11eb-8b7b-5eab8860602c.png)
#
# # SMPLpix Dataset Preparation.
#
# **Author**: [Sergey Prokudin](https://ps.is.mpg.de/people/sprokudin).
# [[Project Page](https://sergeyprokudin.github.io/smplpix/)]
# [[Paper](https://arxiv.org/pdf/2008.06872.pdf)]
# [[Video](https://www.youtube.com/watch?v=JY9t4xUAouk)]
# [[GitHub](https://github.com/sergeyprokudin/smplpix)]
#
# This notebook contains an example workflow for converting a video file to a SMPLpix dataset.
# ### Processing steps:
#
# 1. Download the video of choice, extract frames;
# 2. Extract **2D keypoints**: run [OpenPose](https://github.com/CMU-Perceptual-Computing-Lab/openpose) on the extracted frames;
# 3. Infer **3D human meshes**: run [SMPLify-x](https://github.com/vchoutas/smplify-x) on the extracted frames + keypoints;
# 4. Form dataset **image pairs**, where *input* is SMPL-X mesh render, and *output* is the corresponding target ground truth video frame;
# 5. **Split the data** into train, test and validation, zip and copy to Google Drive.
#
# ### Instructions
#
# 1. Convert a video into our dataset format using this notebook.
# 2. Train a SMPLpix using the training notebook.
#
#
# ### Notes
# * While this will work for small datasets in a Colab runtime, larger datasets will require more compute power;
# * If you would like to train a model on a serious dataset, you should consider copying this to your own workstation and running it there. Some minor modifications will be required, and you will have to install the dependencies separately;
# * Please report issues on the [GitHub issue tracker](https://github.com/sergeyprokudin/smplpix/issues).
#
# If you find this work useful, please consider citing:
# ```bibtex
# @inproceedings{prokudin2021smplpix,
#   title={SMPLpix: Neural Avatars from 3D Human Models},
#   author={Prokudin, Sergey and Black, Michael J and Romero, Javier},
#   booktitle={Proceedings of the IEEE/CVF Winter Conference on Applications of Computer Vision},
#   pages={1810--1819},
#   year={2021}
# }
# ```
#
# Many thanks [Keunhong Park](https://keunhong.com) for providing the [Nerfie dataset preparation template](https://colab.research.google.com/github/google/nerfies/blob/main/notebooks/Nerfies_Capture_Processing.ipynb)!

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Upload the video and extract frames

# %%
# @title Upload a video file (.mp4, .mov, etc.) from your disk, Dropbox, Google Drive or YouTube

# @markdown  This will upload it to the local Colab working directory. You can use a demo video to test the pipeline. The background in the demo was removed with the [Unscreen](https://www.unscreen.com/) service. Alternatively, you can try [PointRend](https://github.com/facebookresearch/detectron2/tree/master/projects/PointRend) segmentation for this purpose. 

import os
from google.colab import files

def download_youtube_video(img_url, save_path, resolution_id=-3):

  print("downloading the video: %s" % img_url)
  res_path = YouTube(img_url).streams.order_by('resolution')[resolution_id].download(save_path)

  return res_path

def download_dropbox_url(url, filepath, chunk_size=1024):

    import requests
    headers = {'user-agent': 'Wget/1.16 (linux-gnu)'}
    r = requests.get(url, stream=True, headers=headers)
    with open(filepath, 'wb') as f:
        for chunk in r.iter_content(chunk_size=chunk_size):
            if chunk:
                f.write(chunk)
    return filepath

# !rm -rf /content/data

from google.colab import drive
drive.mount('/content/gdrive')

VIDEO_SOURCE = 'dropbox' #@param ["youtube", "upload", "google drive", "dropbox"]

if VIDEO_SOURCE == 'dropbox':
  DROPBOX_URL  = 'https://www.dropbox.com/s/rjqwf894ovso218/smplpix_test_video_na.mp4?dl=0' #@param 
  VIDEO_PATH  = '/content/video.mp4' 
  download_dropbox_url(DROPBOX_URL, VIDEO_PATH)
elif VIDEO_SOURCE == 'upload':
  print("Please upload the video: ")
  uploaded = files.upload()
  VIDEO_PATH = os.path.join('/content', list(uploaded.keys())[0])
elif VIDEO_SOURCE == 'youtube':
  # !pip install pytube
  from pytube import YouTube
  YOTUBE_VIDEO_URL  = ''  #@param 
  VIDEO_PATH = download_youtube_video(YOTUBE_VIDEO_URL, '/content/')
elif VIDEO_SOURCE == 'google drive':
  from google.colab import drive
  drive.mount('/content/gdrive')
  GOOGLE_DRIVE_PATH = '' #@param 
  VIDEO_PATH  = GOOGLE_DRIVE_PATH


print("video is uploaded to %s" % VIDEO_PATH)

# %%
# @title Flatten the video into frames


FPS =     1# @param {type:'number'}

# @markdown _Note_: for longer videos, it might make sense to decrease the FPS as it will take 30-60 seconds for SMPLify-X framework to process every frame.



RES_DIR = '/content/data'
FRAMES_DIR = os.path.join(RES_DIR, 'images')
# !rm -rf $RES_DIR
# !mkdir $RES_DIR
# !mkdir $FRAMES_DIR
# !ffmpeg -i "$VIDEO_PATH" -vf fps=$FPS  -qscale:v 2 "$FRAMES_DIR/%05d.png"

from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

def load_img(img_path):

  return np.asarray(Image.open(img_path))/255

test_img_path = os.path.join(FRAMES_DIR, os.listdir(FRAMES_DIR)[0])

test_img = load_img(test_img_path)

plt.figure(figsize=(5, 10))
plt.title("extracted image example")
plt.imshow(test_img)

# %% [markdown]
# ## Step2: Extract 2D body keypoints with OpenPose

# %%
# @title Install OpenPose
# @markdown This will take some time (~10 mins). The code is taken from this [OpenPose Colab notebook](https://colab.research.google.com/github/tugstugi/dl-colab-notebooks/blob/master/notebooks/OpenPose.ipynb).

# %cd /content
import os
from os.path import exists, join, basename, splitext

git_repo_url = 'https://github.com/CMU-Perceptual-Computing-Lab/openpose.git'
project_name = splitext(basename(git_repo_url))[0]
if not exists(project_name):
  # see: https://github.com/CMU-Perceptual-Computing-Lab/openpose/issues/949
  # install new CMake becaue of CUDA10
  # !wget -q https://cmake.org/files/v3.13/cmake-3.13.0-Linux-x86_64.tar.gz
  # !tar xfz cmake-3.13.0-Linux-x86_64.tar.gz --strip-components=1 -C /usr/local

  # clone openpose
  # !git clone -q --depth 1 $git_repo_url
  # download models
  # !wget -O /content/openpose/models/hand/pose_iter_102000.caffemodel https://polybox.ethz.ch/index.php/s/Oim76cuqrDVbdxm/download
  # !wget -O /content/openpose/models/pose/body_25/pose_iter_584000.caffemodel https://polybox.ethz.ch/index.php/s/m5NQAhd7ukVPRoL/download
  # !wget -O /content/openpose/models/face/pose_iter_116000.caffemodel https://polybox.ethz.ch/index.php/s/cEaF1FTpKjjJZbH/download
  # !sed -i 's/execute_process(COMMAND git checkout master WORKING_DIRECTORY ${CMAKE_SOURCE_DIR}\/3rdparty\/caffe)/execute_process(COMMAND git checkout f019d0dfe86f49d1140961f8c7dec22130c83154 WORKING_DIRECTORY ${CMAKE_SOURCE_DIR}\/3rdparty\/caffe)/g' openpose/CMakeLists.txt
  # install system dependencies
  # !apt-get -qq install -y libatlas-base-dev libprotobuf-dev libleveldb-dev libsnappy-dev libhdf5-serial-dev protobuf-compiler libgflags-dev libgoogle-glog-dev liblmdb-dev opencl-headers ocl-icd-opencl-dev libviennacl-dev
  # install python dependencies
  # !pip install -q youtube-dl
  # build openpose
  # !cd openpose && rm -rf build || true && mkdir build && cd build && cmake .. && make -j`nproc`

# %%
# @title Run OpenPose on the extracted frames
# %cd /content
RES_DIR = '/content/data/'
FRAMES_DIR = os.path.join(RES_DIR, 'images')
KEYPOINTS_DIR = os.path.join(RES_DIR, 'keypoints')
OPENPOSE_IMAGES_DIR = os.path.join(RES_DIR, 'openpose_images')
# !mkdir $KEYPOINTS_DIR
# !mkdir $OPENPOSE_IMAGES_DIR

# !cd openpose && ./build/examples/openpose/openpose.bin --image_dir $FRAMES_DIR --write_json $KEYPOINTS_DIR --face --hand --display 0   --write_images $OPENPOSE_IMAGES_DIR

# input_img_path = os.path.join(FRAMES_DIR, sorted(os.listdir(FRAMES_DIR))[0])
# openpose_img_path = os.path.join(OPENPOSE_IMAGES_DIR, sorted(os.listdir(OPENPOSE_IMAGES_DIR))[0])

# test_img = load_img(input_img_path)
# open_pose_img = load_img(openpose_img_path)

# plt.figure(figsize=(10, 10))
# plt.title("Input Frame + Openpose Prediction")
# plt.imshow(np.concatenate([test_img, open_pose_img], 1))

# %% [markdown]
# ## Step3: Infer 3D Human Model with [SMPLify-X](https://smpl-x.is.tue.mpg.de/)

# %%
# @title Install SMPLify-X and other dependencies

# !pip install chumpy
# !pip install smplx
# !git clone https://github.com/vchoutas/smplx
# %cd smplx
# !python setup.py install

#vposer
# !pip install git+https://github.com/nghorbani/configer
# !pip install git+https://github.com/sergeyprokudin/human_body_prior

# !pip install torch==1.1.0
# %cd ..
# !git clone https://github.com/sergeyprokudin/smplify-x
# %cd smplify-x
# !pip install -r requirements.txt

# %%
# @title Upload the SMPL-X model files

# @markdown Proceed to the [official website](https://smpl-x.is.tue.mpg.de/), register and download the zip files with SMPL-X (**models_smplx_v1_1.zip**, ~830MB) and VPoser (**vposer_v1_0.zip**, ~2.5MB) models from the **Downloads** section. 
# @markdown

# @markdown Since uploading large zip files to Colab is relatively slow, we expect you to upload these files to Google Drive instead, link gdrive to the Colab file systems and modify **SMPLX_ZIP_PATH** and **VPOSER_ZIP_PATH** variables accordingly.

# %cd /content/
# from google.colab import drive
# drive.mount('/content/gdrive')

SMPLX_ZIP_PATH = './models_smplx_v1_1.zip' # @param {type:"string"}
VPOSER_ZIP_PATH = './vposer_v1_0.zip' # @param {type:"string"}

SMPLX_MODEL_PATH = './smplx'
# !mkdir $SMPLX_MODEL_PATH
# !unzip -n $SMPLX_ZIP_PATH -d  $SMPLX_MODEL_PATH
VPOSER_MODEL_PATH = './vposer'
# !mkdir $VPOSER_MODEL_PATH
# !unzip -n $VPOSER_ZIP_PATH -d  $VPOSER_MODEL_PATH

# %%
# @title Run SMPLify-X

# @markdown Please select gender of the SMPL-X model:

gender = 'female' #@param ["neutral", "female", "male"]

# @markdown Please keep in mind that estimating 3D body with SMPLify-X framework will take ~30-60 secs, so processing long videos at high FPS might take a long time.

# !rm -rf ../data/smplifyx_results
# %cd /home/cvmlserver/Seohyeon/smplpix/smplify-x
# !git pull origin
# !python smplifyx/main.py --config cfg_files/fit_smplx.yaml \
    --data_folder  /home/cvmlserver/Seohyeon/smplpix/data \
    --output_folder /home/cvmlserver/Seohyeon/smplpix/data/smplifyx_results \
    --visualize=True \
    --gender=$gender \
    --model_folder /home/cvmlserver/Seohyeon/smplpix/smplx/models \
    --vposer_ckpt /home/cvmlserver/Seohyeon/smplpix/vposer/vposer_v1_0 \
    --part_segm_fn smplx_parts_segm.pkl
# Out:
# /home/cvmlserver/Seohyeon/smplpix/smplify-x
# Processing: /home/cvmlserver/Seohyeon/smplpix/data/images/00001.png
# 0
# Found Trained Model: /home/cvmlserver/Seohyeon/smplpix/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Camera initialization done after 2.0138
# Camera initialization final loss 56.4891
# Orientation:   0%|                                        | 0/1 [00:00<?, ?it/s]
#
# Stage 000 done after 2.4682 seconds
# Orientation:   0%|                                        | 0/1 [00:02<?, ?it/s]
# Stage:   0%|                                              | 0/5 [00:02<?, ?it/s]
#
# Stage 001 done after 2.3693 seconds
# Orientation:   0%|                                        | 0/1 [00:04<?, ?it/s]
# Stage:  20%|███████▌                              | 1/5 [00:04<00:09,  2.47s/it]
#
# Stage 002 done after 2.0166 seconds
# Orientation:   0%|                                        | 0/1 [00:06<?, ?it/s]
# Stage:  40%|███████████████▏                      | 2/5 [00:06<00:07,  2.41s/it]
#
# Stage 003 done after 5.9685 seconds
# Orientation:   0%|                                        | 0/1 [00:12<?, ?it/s]
# Stage:  60%|██████████████████████▊               | 3/5 [00:12<00:04,  2.23s/it]
#
# Stage 004 done after 10.3711 seconds
# Orientation:   0%|                                        | 0/1 [00:23<?, ?it/s]
# Stage:  80%|██████████████████████████████▍       | 4/5 [00:23<00:03,  3.71s/it]
# Stage: 100%|██████████████████████████████████████| 5/5 [00:23<00:00,  4.64s/it]
# Body fitting Orientation 0 done after 23.2057 seconds
# Body final loss val = 899.40948
# Orientation: 100%|████████████████████████████████| 1/1 [00:23<00:00, 23.21s/it]
# saved input image to /home/cvmlserver/Seohyeon/smplpix/data/smplifyx_results/images/00001/000/output.png
# 1
# Found Trained Model: /home/cvmlserver/Seohyeon/smplpix/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Camera initialization done after 2.0462
# Camera initialization final loss 279.7006
# Orientation:   0%|                                        | 0/1 [00:00<?, ?it/s]
#
# Stage 000 done after 3.6316 seconds
# Orientation:   0%|                                        | 0/1 [00:03<?, ?it/s]
# Stage:   0%|                                              | 0/5 [00:03<?, ?it/s]
#
# Stage 001 done after 0.6528 seconds
# Orientation:   0%|                                        | 0/1 [00:04<?, ?it/s]
# Stage:  20%|███████▌                              | 1/5 [00:04<00:14,  3.63s/it]
#
# Stage 002 done after 2.6892 seconds
# Orientation:   0%|                                        | 0/1 [00:06<?, ?it/s]
# Stage:  40%|███████████████▏                      | 2/5 [00:06<00:05,  1.88s/it]
#
# Stage 003 done after 6.5452 seconds
# Orientation:   0%|                                        | 0/1 [00:13<?, ?it/s]
# Stage:  60%|██████████████████████▊               | 3/5 [00:13<00:04,  2.25s/it]
#
# Stage 004 done after 17.1624 seconds
# Orientation:   0%|                                        | 0/1 [00:30<?, ?it/s]
# Stage:  80%|██████████████████████████████▍       | 4/5 [00:30<00:03,  3.95s/it]
# Stage: 100%|██████████████████████████████████████| 5/5 [00:30<00:00,  6.14s/it]
# Body fitting Orientation 0 done after 30.6924 seconds
# Body final loss val = 2613.99585
# Orientation: 100%|████████████████████████████████| 1/1 [00:30<00:00, 30.69s/it]
# saved input image to /home/cvmlserver/Seohyeon/smplpix/data/smplifyx_results/images/00001/001/output.png
# Processing: /home/cvmlserver/Seohyeon/smplpix/data/images/00002.png
# 0
# Found Trained Model: /home/cvmlserver/Seohyeon/smplpix/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Camera initialization done after 1.5987
# Camera initialization final loss 135.2937
# Orientation:   0%|                                        | 0/1 [00:00<?, ?it/s]
#
# Stage 000 done after 3.0983 seconds
# Orientation:   0%|                                        | 0/1 [00:03<?, ?it/s]
# Stage:   0%|                                              | 0/5 [00:03<?, ?it/s]
#
# Stage 001 done after 2.1618 seconds
# Orientation:   0%|                                        | 0/1 [00:05<?, ?it/s]
# Stage:  20%|███████▌                              | 1/5 [00:05<00:12,  3.10s/it]
#
# Stage 002 done after 5.1531 seconds
# Orientation:   0%|                                        | 0/1 [00:10<?, ?it/s]
# Stage:  40%|███████████████▏                      | 2/5 [00:10<00:07,  2.55s/it]
#
# Stage 003 done after 6.3907 seconds
# Orientation:   0%|                                        | 0/1 [00:16<?, ?it/s]
# Stage:  60%|██████████████████████▊               | 3/5 [00:16<00:07,  3.74s/it]
#
# Stage 004 done after 6.8775 seconds
# Orientation:   0%|                                        | 0/1 [00:23<?, ?it/s]
# Stage:  80%|██████████████████████████████▍       | 4/5 [00:23<00:04,  4.79s/it]
# Stage: 100%|██████████████████████████████████████| 5/5 [00:23<00:00,  4.74s/it]
# Body fitting Orientation 0 done after 23.6958 seconds
# Body final loss val = 1193.76538
# Orientation: 100%|████████████████████████████████| 1/1 [00:23<00:00, 23.70s/it]
# saved input image to /home/cvmlserver/Seohyeon/smplpix/data/smplifyx_results/images/00002/000/output.png
# 1
# Found Trained Model: /home/cvmlserver/Seohyeon/smplpix/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Camera initialization done after 1.5539
# Camera initialization final loss 412.3835
# Orientation:   0%|                                        | 0/1 [00:00<?, ?it/s]
#
# Stage 000 done after 3.8941 seconds
# Orientation:   0%|                                        | 0/1 [00:03<?, ?it/s]
# Stage:   0%|                                              | 0/5 [00:03<?, ?it/s]
#
# Stage 001 done after 0.8363 seconds
# Orientation:   0%|                                        | 0/1 [00:04<?, ?it/s]
# Stage:  20%|███████▌                              | 1/5 [00:04<00:15,  3.90s/it]
#
# Stage 002 done after 8.6280 seconds
# Orientation:   0%|                                        | 0/1 [00:13<?, ?it/s]
# Stage:  40%|███████████████▏                      | 2/5 [00:13<00:06,  2.10s/it]
#
# Stage 003 done after 6.8570 seconds
# Orientation:   0%|                                        | 0/1 [00:20<?, ?it/s]
# Stage:  60%|██████████████████████▊               | 3/5 [00:20<00:10,  5.08s/it]
#
# Stage 004 done after 16.7889 seconds
# Orientation:   0%|                                        | 0/1 [00:37<?, ?it/s]
# Stage:  80%|██████████████████████████████▍       | 4/5 [00:37<00:05,  5.78s/it]
# Stage: 100%|██████████████████████████████████████| 5/5 [00:37<00:00,  7.40s/it]
# Body fitting Orientation 0 done after 37.0183 seconds
# Body final loss val = 2975.03589
# Orientation: 100%|████████████████████████████████| 1/1 [00:37<00:00, 37.02s/it]
# saved input image to /home/cvmlserver/Seohyeon/smplpix/data/smplifyx_results/images/00002/001/output.png
# Processing: /home/cvmlserver/Seohyeon/smplpix/data/images/00003.png
# 0
# Found Trained Model: /home/cvmlserver/Seohyeon/smplpix/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Camera initialization done after 1.5644
# Camera initialization final loss 206.5874
# Orientation:   0%|                                        | 0/1 [00:00<?, ?it/s]
#
# Stage 000 done after 3.1237 seconds
# Orientation:   0%|                                        | 0/1 [00:03<?, ?it/s]
# Stage:   0%|                                              | 0/5 [00:03<?, ?it/s]
#
# Stage 001 done after 1.7775 seconds
# Orientation:   0%|                                        | 0/1 [00:04<?, ?it/s]
# Stage:  20%|███████▌                              | 1/5 [00:04<00:12,  3.13s/it]
#
# Stage 002 done after 6.4377 seconds
# Orientation:   0%|                                        | 0/1 [00:11<?, ?it/s]
# Stage:  40%|███████████████▏                      | 2/5 [00:11<00:07,  2.33s/it]
#
# Stage 003 done after 6.0067 seconds
# Orientation:   0%|                                        | 0/1 [00:17<?, ?it/s]
# Stage:  60%|██████████████████████▊               | 3/5 [00:17<00:08,  4.21s/it]
#
# Stage 004 done after 11.9136 seconds
# Orientation:   0%|                                        | 0/1 [00:29<?, ?it/s]
# Stage:  80%|██████████████████████████████▍       | 4/5 [00:29<00:04,  4.92s/it]
# Stage: 100%|██████████████████████████████████████| 5/5 [00:29<00:00,  5.85s/it]
# Body fitting Orientation 0 done after 29.2739 seconds
# Body final loss val = 1401.85925
# Orientation: 100%|████████████████████████████████| 1/1 [00:29<00:00, 29.27s/it]
# saved input image to /home/cvmlserver/Seohyeon/smplpix/data/smplifyx_results/images/00003/000/output.png
# 1
# Found Trained Model: /home/cvmlserver/Seohyeon/smplpix/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Camera initialization done after 1.6431
# Camera initialization final loss 457.4843
# Orientation:   0%|                                        | 0/1 [00:00<?, ?it/s]
#
# Stage 000 done after 3.4633 seconds
# Orientation:   0%|                                        | 0/1 [00:03<?, ?it/s]
# Stage:   0%|                                              | 0/5 [00:03<?, ?it/s]
#
# Stage 001 done after 1.5486 seconds
# Orientation:   0%|                                        | 0/1 [00:05<?, ?it/s]
# Stage:  20%|███████▌                              | 1/5 [00:05<00:13,  3.47s/it]
#
# Stage 002 done after 5.3561 seconds
# Orientation:   0%|                                        | 0/1 [00:10<?, ?it/s]
# Stage:  40%|███████████████▏                      | 2/5 [00:10<00:07,  2.34s/it]
#
# Stage 003 done after 10.8990 seconds
# Orientation:   0%|                                        | 0/1 [00:21<?, ?it/s]
# Stage:  60%|██████████████████████▊               | 3/5 [00:21<00:07,  3.72s/it]
#
# Stage 004 done after 17.6147 seconds
# Orientation:   0%|                                        | 0/1 [00:38<?, ?it/s]
# Stage:  80%|██████████████████████████████▍       | 4/5 [00:38<00:06,  6.55s/it]
# Stage: 100%|██████████████████████████████████████| 5/5 [00:38<00:00,  7.78s/it]
# Body fitting Orientation 0 done after 38.8951 seconds
# Body final loss val = 3169.06616
# Orientation: 100%|████████████████████████████████| 1/1 [00:38<00:00, 38.90s/it]
# saved input image to /home/cvmlserver/Seohyeon/smplpix/data/smplifyx_results/images/00003/001/output.png
# Processing: /home/cvmlserver/Seohyeon/smplpix/data/images/00004.png
# 0
# Found Trained Model: /home/cvmlserver/Seohyeon/smplpix/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Camera initialization done after 1.6741
# Camera initialization final loss 232.5125
# Orientation:   0%|                                        | 0/1 [00:00<?, ?it/s]
#
# Stage 000 done after 3.2321 seconds
# Orientation:   0%|                                        | 0/1 [00:03<?, ?it/s]
# Stage:   0%|                                              | 0/5 [00:03<?, ?it/s]
#
# Stage 001 done after 1.5601 seconds
# Orientation:   0%|                                        | 0/1 [00:04<?, ?it/s]
# Stage:  20%|███████▌                              | 1/5 [00:04<00:12,  3.23s/it]
#
# Stage 002 done after 2.7085 seconds
# Orientation:   0%|                                        | 0/1 [00:07<?, ?it/s]
# Stage:  40%|███████████████▏                      | 2/5 [00:07<00:06,  2.25s/it]
#
# Stage 003 done after 9.6490 seconds
# Orientation:   0%|                                        | 0/1 [00:17<?, ?it/s]
# Stage:  60%|██████████████████████▊               | 3/5 [00:17<00:04,  2.46s/it]
#
# Stage 004 done after 11.9747 seconds
# Orientation:   0%|                                        | 0/1 [00:29<?, ?it/s]
# Stage:  80%|██████████████████████████████▍       | 4/5 [00:29<00:05,  5.30s/it]
# Stage: 100%|██████████████████████████████████████| 5/5 [00:29<00:00,  5.83s/it]
# Body fitting Orientation 0 done after 29.1374 seconds
# Body final loss val = 1475.68127
# Orientation: 100%|████████████████████████████████| 1/1 [00:29<00:00, 29.14s/it]
# saved input image to /home/cvmlserver/Seohyeon/smplpix/data/smplifyx_results/images/00004/000/output.png
# 1
# Found Trained Model: /home/cvmlserver/Seohyeon/smplpix/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Camera initialization done after 1.6101
# Camera initialization final loss 476.5237
# Orientation:   0%|                                        | 0/1 [00:00<?, ?it/s]
# Stage:   0%|                                              | 0/5 [00:00<?, ?it/s]
# Stage 000 done after 3.3631 seconds
#
# Orientation:   0%|                                        | 0/1 [00:03<?, ?it/s]
# Stage:  20%|███████▌                              | 1/5 [00:03<00:13,  3.37s/it]
# Stage 001 done after 1.0383 seconds
#
# Orientation:   0%|                                        | 0/1 [00:04<?, ?it/s]
# Stage:  40%|███████████████▏                      | 2/5 [00:04<00:05,  2.00s/it]
# Stage 002 done after 2.4470 seconds
#
# Orientation:   0%|                                        | 0/1 [00:06<?, ?it/s]
# Stage:  60%|██████████████████████▊               | 3/5 [00:06<00:04,  2.20s/it]
# Stage 003 done after 9.7670 seconds
#
# Orientation:   0%|                                        | 0/1 [00:16<?, ?it/s]
# Stage:  80%|██████████████████████████████▍       | 4/5 [00:16<00:05,  5.19s/it]
# Stage 004 done after 16.0036 seconds
#
# Orientation:   0%|                                        | 0/1 [00:32<?, ?it/s]
# Stage: 100%|██████████████████████████████████████| 5/5 [00:32<00:00,  6.53s/it]
# Body fitting Orientation 0 done after 32.6322 seconds
# Body final loss val = 3248.64038
# Orientation: 100%|████████████████████████████████| 1/1 [00:32<00:00, 32.63s/it]
# saved input image to /home/cvmlserver/Seohyeon/smplpix/data/smplifyx_results/images/00004/001/output.png
# Processing: /home/cvmlserver/Seohyeon/smplpix/data/images/00005.png
# 0
# Found Trained Model: /home/cvmlserver/Seohyeon/smplpix/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Camera initialization done after 2.0159
# Camera initialization final loss 271.6597
# Orientation:   0%|                                        | 0/1 [00:00<?, ?it/s]
#
# Stage 000 done after 3.6804 seconds
# Orientation:   0%|                                        | 0/1 [00:03<?, ?it/s]
# Stage:   0%|                                              | 0/5 [00:03<?, ?it/s]
#
# Stage 001 done after 1.8208 seconds
# Orientation:   0%|                                        | 0/1 [00:05<?, ?it/s]
# Stage:  20%|███████▌                              | 1/5 [00:05<00:14,  3.68s/it]
#
# Stage 002 done after 5.2991 seconds
# Orientation:   0%|                                        | 0/1 [00:10<?, ?it/s]
# Stage:  40%|███████████████▏                      | 2/5 [00:10<00:07,  2.59s/it]
#
# Stage 003 done after 5.3704 seconds
# Orientation:   0%|                                        | 0/1 [00:16<?, ?it/s]
# Stage:  60%|██████████████████████▊               | 3/5 [00:16<00:07,  3.83s/it]
#
# Stage 004 done after 7.2245 seconds
# Orientation:   0%|                                        | 0/1 [00:23<?, ?it/s]
# Stage:  80%|██████████████████████████████▍       | 4/5 [00:23<00:04,  4.44s/it]
# Stage: 100%|██████████████████████████████████████| 5/5 [00:23<00:00,  4.68s/it]
# Body fitting Orientation 0 done after 23.4085 seconds
# Body final loss val = 1320.69604
# Orientation: 100%|████████████████████████████████| 1/1 [00:23<00:00, 23.41s/it]
# saved input image to /home/cvmlserver/Seohyeon/smplpix/data/smplifyx_results/images/00005/000/output.png
# 1
# Found Trained Model: /home/cvmlserver/Seohyeon/smplpix/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Camera initialization done after 2.1793
# Camera initialization final loss 334.5852
# Orientation:   0%|                                        | 0/1 [00:00<?, ?it/s]
# Stage:   0%|                                              | 0/5 [00:00<?, ?it/s]
# Stage 000 done after 3.6322 seconds
#
# Orientation:   0%|                                        | 0/1 [00:03<?, ?it/s]
# Stage:  20%|███████▌                              | 1/5 [00:03<00:14,  3.63s/it]
# Stage 001 done after 0.6510 seconds
#
# Orientation:   0%|                                        | 0/1 [00:04<?, ?it/s]
# Stage:  40%|███████████████▏                      | 2/5 [00:04<00:05,  1.88s/it]
# Stage 002 done after 8.9840 seconds
#
# Orientation:   0%|                                        | 0/1 [00:13<?, ?it/s]
# Stage:  60%|██████████████████████▊               | 3/5 [00:13<00:10,  5.13s/it]
# Stage 003 done after 10.1790 seconds
#
# Orientation:   0%|                                        | 0/1 [00:23<?, ?it/s]
# Stage:  80%|██████████████████████████████▍       | 4/5 [00:23<00:07,  7.12s/it]
# Stage 004 done after 15.5896 seconds
#
# Orientation:   0%|                                        | 0/1 [00:39<?, ?it/s]
# Stage: 100%|██████████████████████████████████████| 5/5 [00:39<00:00,  7.81s/it]
# Body fitting Orientation 0 done after 39.0494 seconds
# Body final loss val = 3355.58667
# Orientation: 100%|████████████████████████████████| 1/1 [00:39<00:00, 39.05s/it]
# saved input image to /home/cvmlserver/Seohyeon/smplpix/data/smplifyx_results/images/00005/001/output.png
# Processing: /home/cvmlserver/Seohyeon/smplpix/data/images/00006.png
# 0
# Found Trained Model: /home/cvmlserver/Seohyeon/smplpix/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Camera initialization done after 2.2644
# Camera initialization final loss 215.8568
# Orientation:   0%|                                        | 0/1 [00:00<?, ?it/s]
#
# Stage 000 done after 3.4971 seconds
# Orientation:   0%|                                        | 0/1 [00:03<?, ?it/s]
# Stage:   0%|                                              | 0/5 [00:03<?, ?it/s]
#
# Stage 001 done after 2.5047 seconds
# Orientation:   0%|                                        | 0/1 [00:06<?, ?it/s]
# Stage:  20%|███████▌                              | 1/5 [00:06<00:13,  3.50s/it]
#
# Stage 002 done after 4.0010 seconds
# Orientation:   0%|                                        | 0/1 [00:10<?, ?it/s]
# Stage:  40%|███████████████▏                      | 2/5 [00:10<00:08,  2.92s/it]
#
# Stage 003 done after 7.2370 seconds
# Orientation:   0%|                                        | 0/1 [00:17<?, ?it/s]
# Stage:  60%|██████████████████████▊               | 3/5 [00:17<00:06,  3.41s/it]
#
# Stage 004 done after 11.4230 seconds
# Orientation:   0%|                                        | 0/1 [00:28<?, ?it/s]
# Stage:  80%|██████████████████████████████▍       | 4/5 [00:28<00:04,  4.92s/it]
# Stage: 100%|██████████████████████████████████████| 5/5 [00:28<00:00,  5.74s/it]
# Body fitting Orientation 0 done after 28.6759 seconds
# Body final loss val = 1199.31042
# Orientation: 100%|████████████████████████████████| 1/1 [00:28<00:00, 28.68s/it]
# saved input image to /home/cvmlserver/Seohyeon/smplpix/data/smplifyx_results/images/00006/000/output.png
# 1
# Found Trained Model: /home/cvmlserver/Seohyeon/smplpix/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Camera initialization done after 1.7899
# Camera initialization final loss 352.0164
# Orientation:   0%|                                        | 0/1 [00:00<?, ?it/s]
# Stage:   0%|                                              | 0/5 [00:00<?, ?it/s]
# Stage 000 done after 3.7484 seconds
#
# Orientation:   0%|                                        | 0/1 [00:03<?, ?it/s]
# Stage:  20%|███████▌                              | 1/5 [00:03<00:15,  3.75s/it]
# Stage 001 done after 1.4883 seconds
#
# Orientation:   0%|                                        | 0/1 [00:05<?, ?it/s]
# Stage:  40%|███████████████▏                      | 2/5 [00:05<00:07,  2.42s/it]
# Stage 002 done after 3.9505 seconds
#
# Orientation:   0%|                                        | 0/1 [00:09<?, ?it/s]
# Stage:  60%|██████████████████████▊               | 3/5 [00:09<00:06,  3.12s/it]
# Stage 003 done after 8.9247 seconds
#
# Orientation:   0%|                                        | 0/1 [00:18<?, ?it/s]
# Stage:  80%|██████████████████████████████▍       | 4/5 [00:18<00:05,  5.41s/it]
# Stage 004 done after 12.5119 seconds
#
# Orientation:   0%|                                        | 0/1 [00:30<?, ?it/s]
# Stage: 100%|██████████████████████████████████████| 5/5 [00:30<00:00,  6.13s/it]
# Body fitting Orientation 0 done after 30.6362 seconds
# Body final loss val = 3236.27295
# Orientation: 100%|████████████████████████████████| 1/1 [00:30<00:00, 30.64s/it]
# saved input image to /home/cvmlserver/Seohyeon/smplpix/data/smplifyx_results/images/00006/001/output.png
# Processing: /home/cvmlserver/Seohyeon/smplpix/data/images/00007.png
# 0
# Found Trained Model: /home/cvmlserver/Seohyeon/smplpix/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Camera initialization done after 1.9578
# Camera initialization final loss 191.8500
# Orientation:   0%|                                        | 0/1 [00:00<?, ?it/s]
#
# Stage 000 done after 1.2033 seconds
# Orientation:   0%|                                        | 0/1 [00:01<?, ?it/s]
# Stage:   0%|                                              | 0/5 [00:01<?, ?it/s]
#
# Stage 001 done after 0.9785 seconds
# Orientation:   0%|                                        | 0/1 [00:02<?, ?it/s]
# Stage:  20%|███████▌                              | 1/5 [00:02<00:04,  1.21s/it]
#
# Stage 002 done after 4.9543 seconds
# Orientation:   0%|                                        | 0/1 [00:07<?, ?it/s]
# Stage:  40%|███████████████▏                      | 2/5 [00:07<00:03,  1.07s/it]
#
# Stage 003 done after 5.9921 seconds
# Orientation:   0%|                                        | 0/1 [00:13<?, ?it/s]
# Stage:  60%|██████████████████████▊               | 3/5 [00:13<00:05,  2.85s/it]
#
# Stage 004 done after 10.7800 seconds
# Orientation:   0%|                                        | 0/1 [00:23<?, ?it/s]
# Stage:  80%|██████████████████████████████▍       | 4/5 [00:23<00:04,  4.09s/it]
# Stage: 100%|██████████████████████████████████████| 5/5 [00:23<00:00,  4.78s/it]
# Body fitting Orientation 0 done after 23.9223 seconds
# Body final loss val = 1219.61133
# Orientation: 100%|████████████████████████████████| 1/1 [00:23<00:00, 23.92s/it]
# saved input image to /home/cvmlserver/Seohyeon/smplpix/data/smplifyx_results/images/00007/000/output.png
# 1
# Found Trained Model: /home/cvmlserver/Seohyeon/smplpix/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Camera initialization done after 2.2497
# Camera initialization final loss 304.0851
# Orientation:   0%|                                        | 0/1 [00:00<?, ?it/s]
#
# Stage 000 done after 3.8052 seconds
# Orientation:   0%|                                        | 0/1 [00:03<?, ?it/s]
# Stage:   0%|                                              | 0/5 [00:03<?, ?it/s]
#
# Stage 001 done after 0.5806 seconds
# Orientation:   0%|                                        | 0/1 [00:04<?, ?it/s]
# Stage:  20%|███████▌                              | 1/5 [00:04<00:15,  3.81s/it]
#
# Stage 002 done after 2.4796 seconds
# Orientation:   0%|                                        | 0/1 [00:06<?, ?it/s]
# Stage:  40%|███████████████▏                      | 2/5 [00:06<00:05,  1.91s/it]
#
# Stage 003 done after 8.1628 seconds
# Orientation:   0%|                                        | 0/1 [00:15<?, ?it/s]
# Stage:  60%|██████████████████████▊               | 3/5 [00:15<00:04,  2.17s/it]
#
# Stage 004 done after 18.1735 seconds
# Orientation:   0%|                                        | 0/1 [00:33<?, ?it/s]
# Stage:  80%|██████████████████████████████▍       | 4/5 [00:33<00:04,  4.54s/it]
# Stage: 100%|██████████████████████████████████████| 5/5 [00:33<00:00,  6.64s/it]
# Body fitting Orientation 0 done after 33.2138 seconds
# Body final loss val = 3295.39746
# Orientation: 100%|████████████████████████████████| 1/1 [00:33<00:00, 33.21s/it]
# saved input image to /home/cvmlserver/Seohyeon/smplpix/data/smplifyx_results/images/00007/001/output.png
# Processing: /home/cvmlserver/Seohyeon/smplpix/data/images/00008.png
# 0
# Found Trained Model: /home/cvmlserver/Seohyeon/smplpix/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Camera initialization done after 1.8839
# Camera initialization final loss 192.7811
# Orientation:   0%|                                        | 0/1 [00:00<?, ?it/s]
#
# Stage 000 done after 3.1292 seconds
# Orientation:   0%|                                        | 0/1 [00:03<?, ?it/s]
# Stage:   0%|                                              | 0/5 [00:03<?, ?it/s]
#
# Stage 001 done after 1.4125 seconds
# Orientation:   0%|                                        | 0/1 [00:04<?, ?it/s]
# Stage:  20%|███████▌                              | 1/5 [00:04<00:12,  3.13s/it]
#
# Stage 002 done after 2.3315 seconds
# Orientation:   0%|                                        | 0/1 [00:06<?, ?it/s]
# Stage:  40%|███████████████▏                      | 2/5 [00:06<00:06,  2.12s/it]
#
# Stage 003 done after 10.9862 seconds
# Orientation:   0%|                                        | 0/1 [00:17<?, ?it/s]
# Stage:  60%|██████████████████████▊               | 3/5 [00:17<00:04,  2.22s/it]
#
# Stage 004 done after 12.1718 seconds
# Orientation:   0%|                                        | 0/1 [00:30<?, ?it/s]
# Stage:  80%|██████████████████████████████▍       | 4/5 [00:30<00:05,  5.68s/it]
# Stage: 100%|██████████████████████████████████████| 5/5 [00:30<00:00,  6.01s/it]
# Body fitting Orientation 0 done after 30.0444 seconds
# Body final loss val = 1221.80725
# Orientation: 100%|████████████████████████████████| 1/1 [00:30<00:00, 30.05s/it]
# saved input image to /home/cvmlserver/Seohyeon/smplpix/data/smplifyx_results/images/00008/000/output.png
# 1
# Found Trained Model: /home/cvmlserver/Seohyeon/smplpix/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Camera initialization done after 1.8103
# Camera initialization final loss 303.8948
# Orientation:   0%|                                        | 0/1 [00:00<?, ?it/s]
#
# Stage 000 done after 3.9122 seconds
# Orientation:   0%|                                        | 0/1 [00:03<?, ?it/s]
# Stage:   0%|                                              | 0/5 [00:03<?, ?it/s]
#
# Stage 001 done after 1.8610 seconds
# Orientation:   0%|                                        | 0/1 [00:05<?, ?it/s]
# Stage:  20%|███████▌                              | 1/5 [00:05<00:15,  3.91s/it]
#
# Stage 002 done after 4.0096 seconds
# Orientation:   0%|                                        | 0/1 [00:09<?, ?it/s]
# Stage:  40%|███████████████▏                      | 2/5 [00:09<00:08,  2.71s/it]
#
# Stage 003 done after 8.4981 seconds
# Orientation:   0%|                                        | 0/1 [00:18<?, ?it/s]
# Stage:  60%|██████████████████████▊               | 3/5 [00:18<00:06,  3.30s/it]
#
# Stage 004 done after 13.5751 seconds
# Orientation:   0%|                                        | 0/1 [00:31<?, ?it/s]
# Stage:  80%|██████████████████████████████▍       | 4/5 [00:31<00:05,  5.36s/it]
# Stage: 100%|██████████████████████████████████████| 5/5 [00:31<00:00,  6.37s/it]
# Body fitting Orientation 0 done after 31.8694 seconds
# Body final loss val = 3297.86279
# Orientation: 100%|████████████████████████████████| 1/1 [00:31<00:00, 31.87s/it]
# saved input image to /home/cvmlserver/Seohyeon/smplpix/data/smplifyx_results/images/00008/001/output.png
# Processing: /home/cvmlserver/Seohyeon/smplpix/data/images/00009.png
# 0
# Found Trained Model: /home/cvmlserver/Seohyeon/smplpix/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Camera initialization done after 1.9359
# Camera initialization final loss 215.1298
# Orientation:   0%|                                        | 0/1 [00:00<?, ?it/s]
#
# Stage 000 done after 1.0702 seconds
# Orientation:   0%|                                        | 0/1 [00:01<?, ?it/s]
# Stage:   0%|                                              | 0/5 [00:01<?, ?it/s]
#
# Stage 001 done after 0.8808 seconds
# Orientation:   0%|                                        | 0/1 [00:01<?, ?it/s]
# Stage:  20%|███████▌                              | 1/5 [00:01<00:04,  1.07s/it]
#
# Stage 002 done after 4.8226 seconds
# Orientation:   0%|                                        | 0/1 [00:06<?, ?it/s]
# Stage:  40%|███████████████▏                      | 2/5 [00:06<00:02,  1.04it/s]
#
# Stage 003 done after 7.2331 seconds
# Orientation:   0%|                                        | 0/1 [00:14<?, ?it/s]
# Stage:  60%|██████████████████████▊               | 3/5 [00:14<00:05,  2.73s/it]
#
# Stage 004 done after 10.5439 seconds
# Orientation:   0%|                                        | 0/1 [00:24<?, ?it/s]
# Stage:  80%|██████████████████████████████▍       | 4/5 [00:24<00:04,  4.51s/it]
# Stage: 100%|██████████████████████████████████████| 5/5 [00:24<00:00,  4.91s/it]
# Body fitting Orientation 0 done after 24.5630 seconds
# Body final loss val = 1292.17981
# Orientation: 100%|████████████████████████████████| 1/1 [00:24<00:00, 24.56s/it]
# saved input image to /home/cvmlserver/Seohyeon/smplpix/data/smplifyx_results/images/00009/000/output.png
# 1
# Found Trained Model: /home/cvmlserver/Seohyeon/smplpix/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Camera initialization done after 1.8801
# Camera initialization final loss 318.2102
# Orientation:   0%|                                        | 0/1 [00:00<?, ?it/s]
#
# Stage 000 done after 1.1742 seconds
# Orientation:   0%|                                        | 0/1 [00:01<?, ?it/s]
# Stage:   0%|                                              | 0/5 [00:01<?, ?it/s]
#
# Stage 001 done after 4.7717 seconds
# Orientation:   0%|                                        | 0/1 [00:05<?, ?it/s]
# Stage:  20%|███████▌                              | 1/5 [00:05<00:04,  1.18s/it]
#
# Stage 002 done after 3.4469 seconds
# Orientation:   0%|                                        | 0/1 [00:09<?, ?it/s]
# Stage:  40%|███████████████▏                      | 2/5 [00:09<00:09,  3.29s/it]
#
# Stage 003 done after 8.4533 seconds
# Orientation:   0%|                                        | 0/1 [00:17<?, ?it/s]
# Stage:  60%|██████████████████████▊               | 3/5 [00:17<00:06,  3.36s/it]
#
# Stage 004 done after 16.8975 seconds
# Orientation:   0%|                                        | 0/1 [00:34<?, ?it/s]
# Stage:  80%|██████████████████████████████▍       | 4/5 [00:34<00:05,  5.37s/it]
# Stage: 100%|██████████████████████████████████████| 5/5 [00:34<00:00,  6.95s/it]
# Body fitting Orientation 0 done after 34.7577 seconds
# Body final loss val = 3209.86255
# Orientation: 100%|████████████████████████████████| 1/1 [00:34<00:00, 34.76s/it]
# saved input image to /home/cvmlserver/Seohyeon/smplpix/data/smplifyx_results/images/00009/001/output.png
# Processing: /home/cvmlserver/Seohyeon/smplpix/data/images/00010.png
# 0
# Found Trained Model: /home/cvmlserver/Seohyeon/smplpix/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Camera initialization done after 2.4028
# Camera initialization final loss 281.5348
# Orientation:   0%|                                        | 0/1 [00:00<?, ?it/s]
#
# Stage 000 done after 3.5861 seconds
# Orientation:   0%|                                        | 0/1 [00:03<?, ?it/s]
# Stage:   0%|                                              | 0/5 [00:03<?, ?it/s]
#
# Stage 001 done after 1.4366 seconds
# Orientation:   0%|                                        | 0/1 [00:05<?, ?it/s]
# Stage:  20%|███████▌                              | 1/5 [00:05<00:14,  3.59s/it]
#
# Stage 002 done after 7.5275 seconds
# Orientation:   0%|                                        | 0/1 [00:12<?, ?it/s]
# Stage:  40%|███████████████▏                      | 2/5 [00:12<00:06,  2.32s/it]
#
# Stage 003 done after 8.4317 seconds
# Orientation:   0%|                                        | 0/1 [00:20<?, ?it/s]
# Stage:  60%|██████████████████████▊               | 3/5 [00:20<00:09,  4.70s/it]
#
# Stage 004 done after 6.1699 seconds
# Orientation:   0%|                                        | 0/1 [00:27<?, ?it/s]
# Stage:  80%|██████████████████████████████▍       | 4/5 [00:27<00:06,  6.18s/it]
# Stage: 100%|██████████████████████████████████████| 5/5 [00:27<00:00,  5.43s/it]
# Body fitting Orientation 0 done after 27.1665 seconds
# Body final loss val = 1502.79834
# Orientation: 100%|████████████████████████████████| 1/1 [00:27<00:00, 27.17s/it]
# saved input image to /home/cvmlserver/Seohyeon/smplpix/data/smplifyx_results/images/00010/000/output.png
# 1
# Found Trained Model: /home/cvmlserver/Seohyeon/smplpix/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Camera initialization done after 2.0201
# Camera initialization final loss 359.1294
# Orientation:   0%|                                        | 0/1 [00:00<?, ?it/s]
#
# Stage 000 done after 3.5670 seconds
# Orientation:   0%|                                        | 0/1 [00:03<?, ?it/s]
# Stage:   0%|                                              | 0/5 [00:03<?, ?it/s]
#
# Stage 001 done after 1.7954 seconds
# Orientation:   0%|                                        | 0/1 [00:05<?, ?it/s]
# Stage:  20%|███████▌                              | 1/5 [00:05<00:14,  3.57s/it]
#
# Stage 002 done after 3.8786 seconds
# Orientation:   0%|                                        | 0/1 [00:09<?, ?it/s]
# Stage:  40%|███████████████▏                      | 2/5 [00:09<00:07,  2.53s/it]
#
# Stage 003 done after 9.1384 seconds
# Orientation:   0%|                                        | 0/1 [00:18<?, ?it/s]
# Stage:  60%|██████████████████████▊               | 3/5 [00:18<00:06,  3.15s/it]
#
# Stage 004 done after 6.3331 seconds
# Orientation:   0%|                                        | 0/1 [00:24<?, ?it/s]
# Stage:  80%|██████████████████████████████▍       | 4/5 [00:24<00:05,  5.51s/it]
# Stage: 100%|██████████████████████████████████████| 5/5 [00:24<00:00,  4.94s/it]
# Body fitting Orientation 0 done after 24.7251 seconds
# Body final loss val = 3523.78589
# Orientation: 100%|████████████████████████████████| 1/1 [00:24<00:00, 24.73s/it]
# saved input image to /home/cvmlserver/Seohyeon/smplpix/data/smplifyx_results/images/00010/001/output.png
# Processing: /home/cvmlserver/Seohyeon/smplpix/data/images/00011.png
# 0
# Found Trained Model: /home/cvmlserver/Seohyeon/smplpix/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Camera initialization done after 1.5027
# Camera initialization final loss 244.5703
# Orientation:   0%|                                        | 0/1 [00:00<?, ?it/s]
# Stage:   0%|                                              | 0/5 [00:00<?, ?it/s]
# Stage 000 done after 3.1611 seconds
#
# Orientation:   0%|                                        | 0/1 [00:03<?, ?it/s]
# Stage:  20%|███████▌                              | 1/5 [00:03<00:12,  3.16s/it]
# Stage 001 done after 2.1813 seconds
#
# Orientation:   0%|                                        | 0/1 [00:05<?, ?it/s]
# Stage:  40%|███████████████▏                      | 2/5 [00:05<00:07,  2.59s/it]
# Stage 002 done after 4.1714 seconds
#
# Orientation:   0%|                                        | 0/1 [00:09<?, ?it/s]
# Stage:  60%|██████████████████████▊               | 3/5 [00:09<00:06,  3.31s/it]
# Stage 003 done after 8.1064 seconds
#
# Orientation:   0%|                                        | 0/1 [00:17<?, ?it/s]
# Stage:  80%|██████████████████████████████▍       | 4/5 [00:17<00:05,  5.21s/it]
# Stage 004 done after 13.1221 seconds
#
# Orientation:   0%|                                        | 0/1 [00:30<?, ?it/s]
# Stage: 100%|██████████████████████████████████████| 5/5 [00:30<00:00,  6.15s/it]
# Body fitting Orientation 0 done after 30.7568 seconds
# Body final loss val = 1399.94238
# Orientation: 100%|████████████████████████████████| 1/1 [00:30<00:00, 30.76s/it]
# saved input image to /home/cvmlserver/Seohyeon/smplpix/data/smplifyx_results/images/00011/000/output.png
# 1
# Found Trained Model: /home/cvmlserver/Seohyeon/smplpix/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Camera initialization done after 1.6960
# Camera initialization final loss 328.4116
# Orientation:   0%|                                        | 0/1 [00:00<?, ?it/s]
#
# Stage 000 done after 1.7395 seconds
# Orientation:   0%|                                        | 0/1 [00:01<?, ?it/s]
# ...
# Stage: 100%|██████████████████████████████████████| 5/5 [00:19<00:00,  3.95s/it]
# Body fitting Orientation 0 done after 19.7569 seconds
# Body final loss val = 1794.77783
# Orientation: 100%|████████████████████████████████| 1/1 [00:19<00:00, 19.76s/it]
# saved input image to /home/cvmlserver/Seohyeon/smplpix/data/smplifyx_results/images/00085/000/output.png
# 1
# Found Trained Model: /home/cvmlserver/Seohyeon/smplpix/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Camera initialization done after 0.8660
# Camera initialization final loss 364.8065
# Orientation:   0%|                                        | 0/1 [00:00<?, ?it/s]
# Stage:   0%|                                              | 0/5 [00:00<?, ?it/s]
# Stage 000 done after 3.3917 seconds
#
# Orientation:   0%|                                        | 0/1 [00:03<?, ?it/s]
# Stage:  20%|███████▌                              | 1/5 [00:03<00:13,  3.39s/it]
# Stage 001 done after 0.2967 seconds
#
# Orientation:   0%|                                        | 0/1 [00:03<?, ?it/s]
# Stage:  40%|███████████████▏                      | 2/5 [00:03<00:04,  1.57s/it]
# Stage 002 done after 1.4523 seconds
#
# Orientation:   0%|                                        | 0/1 [00:05<?, ?it/s]
# Stage:  60%|██████████████████████▊               | 3/5 [00:05<00:03,  1.52s/it]
# Stage 003 done after 8.2193 seconds
#
# Orientation:   0%|                                        | 0/1 [00:13<?, ?it/s]
# Stage:  80%|██████████████████████████████▍       | 4/5 [00:13<00:04,  4.16s/it]
# Stage 004 done after 29.0684 seconds
#
# Orientation:   0%|                                        | 0/1 [00:42<?, ?it/s]
# Stage: 100%|██████████████████████████████████████| 5/5 [00:42<00:00,  8.49s/it]
# Body fitting Orientation 0 done after 42.4352 seconds
# Body final loss val = 2030.08582
# Orientation: 100%|████████████████████████████████| 1/1 [00:42<00:00, 42.44s/it]
# saved input image to /home/cvmlserver/Seohyeon/smplpix/data/smplifyx_results/images/00085/001/output.png
# Processing: /home/cvmlserver/Seohyeon/smplpix/data/images/00086.png
# 0
# Found Trained Model: /home/cvmlserver/Seohyeon/smplpix/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Camera initialization done after 1.9628
# Camera initialization final loss 300.4544
# Orientation:   0%|                                        | 0/1 [00:00<?, ?it/s]
#
# Stage 000 done after 4.8779 seconds
# Orientation:   0%|                                        | 0/1 [00:04<?, ?it/s]
# Stage:   0%|                                              | 0/5 [00:04<?, ?it/s]
#
# Stage 001 done after 2.0854 seconds
# Orientation:   0%|                                        | 0/1 [00:06<?, ?it/s]
# Stage:  20%|███████▌                              | 1/5 [00:06<00:19,  4.88s/it]
#
# Stage 002 done after 4.0578 seconds
# Orientation:   0%|                                        | 0/1 [00:11<?, ?it/s]
# Stage:  40%|███████████████▏                      | 2/5 [00:11<00:09,  3.24s/it]
#
# Stage 003 done after 10.7868 seconds
# Orientation:   0%|                                        | 0/1 [00:21<?, ?it/s]
# Stage:  60%|██████████████████████▊               | 3/5 [00:21<00:07,  3.61s/it]
#
# Stage 004 done after 11.6553 seconds
# Orientation:   0%|                                        | 0/1 [00:33<?, ?it/s]
# Stage:  80%|██████████████████████████████▍       | 4/5 [00:33<00:06,  6.45s/it]
# Stage: 100%|██████████████████████████████████████| 5/5 [00:33<00:00,  6.70s/it]
# Body fitting Orientation 0 done after 33.4782 seconds
# Body final loss val = 2537.05005
# Orientation: 100%|████████████████████████████████| 1/1 [00:33<00:00, 33.48s/it]
# saved input image to /home/cvmlserver/Seohyeon/smplpix/data/smplifyx_results/images/00086/000/output.png
# 1
# Found Trained Model: /home/cvmlserver/Seohyeon/smplpix/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Camera initialization done after 1.4554
# Camera initialization final loss 97.2989
# Orientation:   0%|                                        | 0/1 [00:00<?, ?it/s]
#
# Stage 000 done after 4.1254 seconds
# Orientation:   0%|                                        | 0/1 [00:04<?, ?it/s]
# Stage:   0%|                                              | 0/5 [00:04<?, ?it/s]
#
# Stage 001 done after 0.5330 seconds
# Orientation:   0%|                                        | 0/1 [00:04<?, ?it/s]
# Stage:  20%|███████▌                              | 1/5 [00:04<00:16,  4.13s/it]
#
# Stage 002 done after 3.6336 seconds
# Orientation:   0%|                                        | 0/1 [00:08<?, ?it/s]
# Stage:  40%|███████████████▏                      | 2/5 [00:08<00:06,  2.01s/it]
#
# Stage 003 done after 9.5925 seconds
# Orientation:   0%|                                        | 0/1 [00:17<?, ?it/s]
# Stage:  60%|██████████████████████▊               | 3/5 [00:17<00:05,  2.75s/it]
#
# Stage 004 done after 14.6689 seconds
# Orientation:   0%|                                        | 0/1 [00:32<?, ?it/s]
# Stage:  80%|██████████████████████████████▍       | 4/5 [00:32<00:05,  5.45s/it]
# Stage: 100%|██████████████████████████████████████| 5/5 [00:32<00:00,  6.51s/it]
# Body fitting Orientation 0 done after 32.5658 seconds
# Body final loss val = 1718.27649
# Orientation: 100%|████████████████████████████████| 1/1 [00:32<00:00, 32.57s/it]
# saved input image to /home/cvmlserver/Seohyeon/smplpix/data/smplifyx_results/images/00086/001/output.png
# Processing: /home/cvmlserver/Seohyeon/smplpix/data/images/00087.png
# 0
# Found Trained Model: /home/cvmlserver/Seohyeon/smplpix/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Camera initialization done after 2.1570
# Camera initialization final loss 75.7902
# Orientation:   0%|                                        | 0/1 [00:00<?, ?it/s]
#
# Stage 000 done after 3.2942 seconds
# Orientation:   0%|                                        | 0/1 [00:03<?, ?it/s]
# Stage:   0%|                                              | 0/5 [00:03<?, ?it/s]
#
# Stage 001 done after 1.6918 seconds
# Orientation:   0%|                                        | 0/1 [00:04<?, ?it/s]
# Stage:  20%|███████▌                              | 1/5 [00:04<00:13,  3.30s/it]
#
# Stage 002 done after 4.7058 seconds
# Orientation:   0%|                                        | 0/1 [00:09<?, ?it/s]
# Stage:  40%|███████████████▏                      | 2/5 [00:09<00:07,  2.35s/it]
#
# Stage 003 done after 11.3831 seconds
# Orientation:   0%|                                        | 0/1 [00:21<?, ?it/s]
# Stage:  60%|██████████████████████▊               | 3/5 [00:21<00:06,  3.43s/it]
#
# Stage 004 done after 18.6358 seconds
# Orientation:   0%|                                        | 0/1 [00:39<?, ?it/s]
# Stage:  80%|██████████████████████████████▍       | 4/5 [00:39<00:06,  6.57s/it]
# Stage: 100%|██████████████████████████████████████| 5/5 [00:39<00:00,  7.94s/it]
# Body fitting Orientation 0 done after 39.7232 seconds
# Body final loss val = 1563.82959
# Orientation: 100%|████████████████████████████████| 1/1 [00:39<00:00, 39.72s/it]
# saved input image to /home/cvmlserver/Seohyeon/smplpix/data/smplifyx_results/images/00087/000/output.png
# 1
# Found Trained Model: /home/cvmlserver/Seohyeon/smplpix/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Camera initialization done after 2.1247
# Camera initialization final loss 515.4523
# Orientation:   0%|                                        | 0/1 [00:00<?, ?it/s]
#
# Stage 000 done after 5.5120 seconds
# Orientation:   0%|                                        | 0/1 [00:05<?, ?it/s]
# Stage:   0%|                                              | 0/5 [00:05<?, ?it/s]
#
# Stage 001 done after 0.3646 seconds
# Orientation:   0%|                                        | 0/1 [00:05<?, ?it/s]
# Stage:  20%|███████▌                              | 1/5 [00:05<00:22,  5.51s/it]
#
# Stage 002 done after 4.7438 seconds
# Orientation:   0%|                                        | 0/1 [00:10<?, ?it/s]
# Stage:  40%|███████████████▏                      | 2/5 [00:10<00:07,  2.49s/it]
#
# Stage 003 done after 13.1111 seconds
# Orientation:   0%|                                        | 0/1 [00:23<?, ?it/s]
# Stage:  60%|██████████████████████▊               | 3/5 [00:23<00:07,  3.52s/it]
#
# Stage 004 done after 17.3296 seconds
# Orientation:   0%|                                        | 0/1 [00:41<?, ?it/s]
# Stage:  80%|██████████████████████████████▍       | 4/5 [00:41<00:07,  7.31s/it]
# Stage: 100%|██████████████████████████████████████| 5/5 [00:41<00:00,  8.21s/it]
# Body fitting Orientation 0 done after 41.0740 seconds
# Body final loss val = 2972.66211
# Orientation: 100%|████████████████████████████████| 1/1 [00:41<00:00, 41.07s/it]
# saved input image to /home/cvmlserver/Seohyeon/smplpix/data/smplifyx_results/images/00087/001/output.png
# Processing: /home/cvmlserver/Seohyeon/smplpix/data/images/00088.png
# 0
# Found Trained Model: /home/cvmlserver/Seohyeon/smplpix/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Camera initialization done after 2.1124
# Camera initialization final loss 76.2488
# Orientation:   0%|                                        | 0/1 [00:00<?, ?it/s]
#
# Stage 000 done after 3.4642 seconds
# Orientation:   0%|                                        | 0/1 [00:03<?, ?it/s]
# Stage:   0%|                                              | 0/5 [00:03<?, ?it/s]
#
# Stage 001 done after 2.0112 seconds
# Orientation:   0%|                                        | 0/1 [00:05<?, ?it/s]
# Stage:  20%|███████▌                              | 1/5 [00:05<00:13,  3.47s/it]
#
# Stage 002 done after 4.0768 seconds
# Orientation:   0%|                                        | 0/1 [00:09<?, ?it/s]
# Stage:  40%|███████████████▏                      | 2/5 [00:09<00:07,  2.61s/it]
#
# Stage 003 done after 19.6619 seconds
# Orientation:   0%|                                        | 0/1 [00:29<?, ?it/s]
# Stage:  60%|██████████████████████▊               | 3/5 [00:29<00:06,  3.28s/it]
#
# Stage 004 done after 13.9693 seconds
# Orientation:   0%|                                        | 0/1 [00:43<?, ?it/s]
# Stage:  80%|██████████████████████████████▍       | 4/5 [00:43<00:09,  9.75s/it]
# Stage: 100%|██████████████████████████████████████| 5/5 [00:43<00:00,  8.64s/it]
# Body fitting Orientation 0 done after 43.1966 seconds
# Body final loss val = 1551.67114
# Orientation: 100%|████████████████████████████████| 1/1 [00:43<00:00, 43.20s/it]
# saved input image to /home/cvmlserver/Seohyeon/smplpix/data/smplifyx_results/images/00088/000/output.png
# 1
# Found Trained Model: /home/cvmlserver/Seohyeon/smplpix/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Camera initialization done after 1.7654
# Camera initialization final loss 497.3041
# Orientation:   0%|                                        | 0/1 [00:00<?, ?it/s]
# Stage:   0%|                                              | 0/5 [00:00<?, ?it/s]
# Stage 000 done after 3.7126 seconds
#
# Orientation:   0%|                                        | 0/1 [00:03<?, ?it/s]
# Stage:  20%|███████▌                              | 1/5 [00:03<00:14,  3.71s/it]
# Stage 001 done after 0.5209 seconds
#
# Orientation:   0%|                                        | 0/1 [00:04<?, ?it/s]
# Stage:  40%|███████████████▏                      | 2/5 [00:04<00:05,  1.84s/it]
# Stage 002 done after 5.5590 seconds
#
# Orientation:   0%|                                        | 0/1 [00:09<?, ?it/s]
# Stage:  60%|██████████████████████▊               | 3/5 [00:09<00:07,  3.54s/it]
# Stage 003 done after 19.9913 seconds
#
# Orientation:   0%|                                        | 0/1 [00:29<?, ?it/s]
# Stage:  80%|██████████████████████████████▍       | 4/5 [00:29<00:10, 10.03s/it]
# Stage 004 done after 13.8642 seconds
#
# Orientation:   0%|                                        | 0/1 [00:43<?, ?it/s]
# Stage: 100%|██████████████████████████████████████| 5/5 [00:43<00:00,  8.73s/it]
# Body fitting Orientation 0 done after 43.6628 seconds
# Body final loss val = 2970.86011
# Orientation: 100%|████████████████████████████████| 1/1 [00:43<00:00, 43.66s/it]
# saved input image to /home/cvmlserver/Seohyeon/smplpix/data/smplifyx_results/images/00088/001/output.png
# Processing the data took: 01 hours, 22 minutes, 29 seconds
